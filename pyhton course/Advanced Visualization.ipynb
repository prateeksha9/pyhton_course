# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Desktop\\pyhton course'

# %%
movies=pd.read_csv('C:\\Users\\Dell\\Desktop\\test\\Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings',
       'BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
##changing to category type from object

movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): [(500) Days of Summer, 10,000 B.C., 12 Rounds, 127 Hours, ..., Youth in Revolt, Zodiac, Zombieland, Zookeeper]

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.unique()
# Out:
# [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]
# Categories (7, object): [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
##doesn't show categorical variable
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions
# count    559.000000       559.000000      559.000000
# mean      47.309481        58.744186       50.236136
# std       26.413091        16.826887       48.731817
# min        0.000000         0.000000        0.000000
# 25%       25.000000        47.000000       20.000000
# 50%       46.000000        58.000000       35.000000
# 75%       70.000000        72.000000       65.000000
# max       97.000000        96.000000      300.000000

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
##jointplots

j = sns.jointplot(data = movies, y="AudienceRatings", x="CriticRating", kind="hex")

# %%
##histogram
sns.set_style("darkgrid")
j1 = plt.hist(movies.CriticRating, bins=15)

# %%
j1 = plt.hist(movies.AudienceRatings, bins=15)

# %%
movies.Genre=="Comedy"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 554     True
# 555     True
# 556    False
# 557    False
# 558     True
# Name: Genre, Length: 559, dtype: bool

# %%
movies[movies.Genre=="Comedy"]
# Out:
#                                    Film   Genre  CriticRating  \
# 0                 (500) Days of Summer   Comedy            87
# 4                             17 Again   Comedy            55
# 6                            27 Dresses  Comedy            40
# 8                    30 Minutes or Less  Comedy            43
# 9                                 50/50  Comedy            93
# ..                                  ...     ...           ...
# 552       You Don't Mess with the Zohan  Comedy            36
# 553  You Will Meet a Tall Dark Stranger  Comedy            43
# 554                       Your Highness  Comedy            26
# 555                     Youth in Revolt  Comedy            68
# 558                           Zookeeper  Comedy            14
#
#      AudienceRatings  BudgetMillions  Year
# 0                 81               8  2009
# 4                 70              20  2009
# 6                 71              30  2008
# 8                 48              28  2011
# ...

# %%
##stacked histogram

plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=="Action"].BudgetMillions)
plt.hist(movies[movies.Genre=="Thriller"].BudgetMillions)
plt.hist(movies[movies.Genre=="Comedy"].BudgetMillions)
plt.hist(movies[movies.Genre=="Drama"].BudgetMillions)
plt.hist(movies[movies.Genre=="Adventure"].BudgetMillions)
plt.hist(movies[movies.Genre=="Horror"].BudgetMillions)
plt.hist(movies[movies.Genre=="Romance"].BudgetMillions)
plt.show()

# %%
plt.hist([movies[movies.Genre=="Action"].BudgetMillions,\
         movies[movies.Genre=="Thriller"].BudgetMillions],\
         bins=15,stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 =list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)
h=plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.legend()

# %%
#Kernel Density Estimate Plot

# %%
vis1 = sns.lmplot(data = movies, y="AudienceRatings", x="CriticRating",
                 fit_reg=False ,hue="Genre",
                 size=5, aspect=1)

# %%
k1=sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True,
               shade_lowest=False)

# %%
#subplot

k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings,
               shade_lowest=False)

# %%
k1=sns.kdeplot(movies.BudgetMillions, movies.CriticRating,
               shade_lowest=False)

# %%
f, axes =plt.subplots(1,2, figsize = (12,6))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings,
               shade_lowest=False, ax=axes[0])

k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating,
               shade_lowest=False, ax=axes[1])

# %%
##violinplots


#z=sns.violinplot(data=movies, x='Genre', y='CriticRating')
z=sns.violinplot(data=movies[movies.Genre=='Drama'], x='Genre', y='CriticRating')

# %%
#z=sns.boxplot(data=movies, x='Genre', y='CriticRating')
z=sns.boxplot(data=movies[movies.Genre=='Drama'], x='Genre', y='CriticRating')

# %%
##creating a facet grid

g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
#movies.Genre.unique()

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g=g.map(plt.scatter, 'CriticRating', 'AudienceRatings')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g=g.map(plt.hist, 'BudgetMillions')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws=dict(s=50, linewidth=0.5, edgecolor="black")
g=g.map(plt.scatter, 'CriticRating', 'AudienceRatings', **kws)

# %%
##coordinates and diagonals

g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws=dict(s=50, linewidth=0.5, edgecolor="black")
g=g.map(plt.scatter, 'CriticRating', 'AudienceRatings', **kws)
g.set(xlim=(0,100), ylim=(0,100))   ##scale
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--")  ##diagonal
g.add_legend()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Building Dashboard


sns.set_style("darkgrid")
f,axes = plt.subplots(2,2,figsize = (15,15))

k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings,
               shade_lowest=False,shade=True,cmap='Blues', ax=axes[0,0])
k1b=sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings,
                shade_lowest=False,cmap='Blues',ax=axes[0,0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating,
               shade_lowest=False, ax=axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z=sns.boxplot(data=movies[movies.Genre=='Drama'], x='Genre', y='CriticRating',
             ax=axes[1,1])

k1=sns.kdeplot(movies.CriticRating, movies.AudienceRatings, shade=True,
               shade_lowest=False, ax=axes[1,0])

# %%
#styling
